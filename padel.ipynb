# %% [markdown]
# Use PaDEL library

# %%
import pandas as pd

# %%
# !pip install padelpy
# Out:
# ...
# [notice] A new release of pip available: 22.3.1 -> 23.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# Use THF as Example

# %%
from padelpy import from_smiles

# %%
descriptors = from_smiles('C1CCOC1')

# %%
print(descriptors)
# Out:
# {'nAcid': '0', 'ALogP': '-0.7069000000000004', 'ALogp2': '0.4997076100000006', 'AMR': '16.8667', 'apol': '13.176344000000002', 'naAromAtom': '0', 'nAromBond': '0', 'nAtom': '13', 'nHeavyAtom': '5', 'nH': '8', 'nB': '0', 'nC': '4', 'nN': '0', 'nO': '1', 'nS': '0', 'nP': '0', 'nF': '0.0', 'nCl': '0.0', 'nBr': '0.0', 'nI': '0.0', 'nX': '0.0', 'ATS0m': '841.1529970000001', 'ATS1m': '913.9770449999997', 'ATS2m': '1030.977620999999', 'ATS3m': '221.98579200000003', 'ATS4m': '12.192768000000001', 'ATS5m': '0.0', 'ATS6m': '0.0', 'ATS7m': '0.0', 'ATS8m': '0.0', 'ATS0v': '2159.1283394091183', 'ATS1v': '2793.9026403637813', 'ATS2v': '3705.2386060714443', 'ATS3v': '2077.8988521192537', 'ATS4v': '373.00493317116315', 'ATS5v': '0.0', 'ATS6v': '0.0', 'ATS7v': '0.0', 'ATS8v': '0.0', 'ATS0e': '97.26149199999998', 'ATS1e': '99.63037200000001', 'ATS2e': '192.8594280000001', 'ATS3e': '203.91782400000017', 'ATS4e': '80.62156799999998', 'ATS5e': '0.0', 'ATS6e': '0.0', 'ATS7e': '0.0', 'ATS8e': '0.0', 'ATS0p
# ...

# %%
df = pd.DataFrame(descriptors, index=[0])
df
# Out:
#   nAcid                ALogP              ALogp2      AMR                apol  \
# 0     0  -0.7069000000000004  0.4997076100000006  16.8667  13.176344000000002
#
#   naAromAtom nAromBond nAtom nHeavyAtom nH  ...                 P1s  \
# 0          0         0    13          5  8  ...  0.5885414497687216
#
#                    P2s                 E1s                  E2s  \
# 0  0.26226323858330913  0.5366134125005254  0.46111981336559776
#
#                   E3s                  Ts                  As  \
# 0  0.5026497250950231  3.4296742283145596  3.3087066843657267
#
#                   Vs                  Ks                  Ds
# 0  7.667407751538741  0.3828121746530823  1.5003829509611464
#
# [1 rows x 1875 columns]

# %% [markdown]
# Use Material Project

# %%
# !pip install mp-api
# Out:
# ...
# [notice] A new release of pip available: 22.3.1 -> 23.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from mp_api.client import MPRester

# %%
from pymatgen.ext.matproj import MPRester

# %%
API_KEY = '2LEgLdcZlD5yNx6U52O1qsDwuXSnVRVv'
mpr = MPRester(API_KEY)
# Out:
# C:\Users\user\PycharmProjects\pythonProject4\venv\Lib\site-packages\mp_api\client\mprester.py:146: UserWarning: mpcontribs-client not installed. Install the package to query MPContribs data, or construct pourbaix diagrams: 'pip install mpcontribs-client'
#   warnings.warn(

# %%
data =  mpr.get_entries('CCC')
# Out:
# Retrieving ThermoDoc documents:   0%|          | 0/62 [00:00<?, ?it/s]

# %%
for entry in data:
    print(entry)
# Out:
# mp-1182029-GGA ComputedStructureEntry - C1           (C)
# Energy (Uncorrected)     = -8.2263   eV (-8.2263  eV/atom)
# Correction               = 0.0000    eV (0.0000   eV/atom)
# Energy (Final)           = -8.2263   eV (-8.2263  eV/atom)
# Energy Adjustments:
#   None
# Parameters:
#   potcar_spec            = [{'titel': 'PAW_PBE C 08Apr2002', 'hash': 'c0a8167dbb174fe492a3db7f5006c0f8'}]
#   is_hubbard             = False
#   hubbards               = {}
#   run_type               = GGA
# Data:
#   oxide_type             = None
#   aspherical             = True
#   last_updated           = 2020-11-11 23:53:35.831000
#   task_id                = mp-1794074
#   material_id            = mp-1182029
#   oxidation_states       = {}
#   run_type               = GGA
# mp-667273-GGA ComputedStructureEntry - C60          (C)
# Energy (Uncorrected)     = -530.2793 eV (-8.8380  eV/atom)
# Correction               = 0.0000    eV (0.0000   eV/atom)
# ...

# %%
for entry in data:
    descriptor_list = [attr for attr in dir(entry) if not callable(getattr(entry, attr)) and not attr.startswith("__")]
    print(f"Available descriptors: {descriptor_list}")
# Out:
# Available descriptors: ['REDIRECT', '_abc_impl', '_composition', '_energy', '_structure', 'composition', 'correction', 'correction_per_atom', 'correction_uncertainty_per_atom', 'data', 'energy', 'energy_adjustments', 'energy_per_atom', 'entry_id', 'is_element', 'name', 'parameters', 'structure', 'uncorrected_energy', 'uncorrected_energy_per_atom']
# Available descriptors: ['REDIRECT', '_abc_impl', '_composition', '_energy', '_structure', 'composition', 'correction', 'correction_per_atom', 'correction_uncertainty_per_atom', 'data', 'energy', 'energy_adjustments', 'energy_per_atom', 'entry_id', 'is_element', 'name', 'parameters', 'structure', 'uncorrected_energy', 'uncorrected_energy_per_atom']
# ...
